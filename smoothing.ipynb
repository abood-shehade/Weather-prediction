# %%
import pandas as pd
import numpy as np
aqaba = pd.read_csv('Datasets-Ready/Aqaba_Ready.csv')
ghor = pd.read_csv('Datasets-Ready/ghor_Ready.csv')
irbid = pd.read_csv('Datasets-Ready/Irbid_Ready.csv')
irwaished = pd.read_csv('Datasets-Ready/Irwaished_Ready.csv')
maan = pd.read_csv('Datasets-Ready/Maan_Ready.csv')
mafraq = pd.read_csv('Datasets-Ready/Mafraq_Ready.csv')
amman = pd.read_csv('Datasets-Ready/Amman_Ready.csv')
safawi = pd.read_csv('Datasets-Ready/Safawi_Ready.csv')

# %%
aqaba.columns
# Out:
# Index(['Unnamed: 0', 'Air Dew Point', 'Air Temperature (OC)', 'Humidity %',
#        'Atmospheric Pressure', 'Liquid Precipitation', 'Cloud Cover %',
#        'Wind_U', 'Wind_V'],
#       dtype='object')

# %%
violent_columns = ['Air Dew Point', 'Wind_U', 'Wind_V']

# %%
df = amman.copy()

# %%
# Out:
# C:\Users\20210291\AppData\Local\Temp\ipykernel_27284\573607829.py:2: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[col] = df[col].rolling(window=15, center=True).mean().fillna(method='bfill').fillna(method='ffill')

# %%
df['Unnamed: 0'] = pd.to_datetime(df['Unnamed: 0'])
df.set_index('Unnamed: 0', inplace = True)

# %%
df = df[(df.index > pd.to_datetime('2023-01-01 00:00:00')) & (df.index < pd.to_datetime('2023-01-31 00:00:00'))]

# %%
df2 = df.copy()
for col in violent_columns:
    df[col] = df[col].rolling(window=15, center=True).mean().fillna(method='bfill').fillna(method='ffill')
# Out:
# C:\Users\20210291\AppData\Local\Temp\ipykernel_27284\2621496686.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[col] = df[col].rolling(window=15, center=True).mean().fillna(method='bfill').fillna(method='ffill')

# %%
df['Atmospheric Pressure'].plot()
# Out:
# <Axes: xlabel='Unnamed: 0'>

# %%
df2['Atmospheric Pressure'].plot()
# Out:
# <Axes: xlabel='Unnamed: 0'>

# %%
df['Atmospheric Pressure'] = df['Atmospheric Pressure'].rolling(window=15, center=True).mean().fillna(method='bfill').fillna(method='ffill')
# Out:
# C:\Users\20210291\AppData\Local\Temp\ipykernel_27284\133174178.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Atmospheric Pressure'] = df['Atmospheric Pressure'].rolling(window=15, center=True).mean().fillna(method='bfill').fillna(method='ffill')

# %%
datasets = [aqaba, ghor, irbid, irwaished, maan, mafraq, amman, safawi]
names = ['aqaba', 'ghor', 'irbid', 'irwaished', 'maan', 'mafraq', 'amman', 'safawi']

# %%
final = []

# %%
for i in range(len(datasets)):
    df = datasets[i].copy()
    for col in violent_columns:
        df[col] = df[col].rolling(window=15, center=True).mean().fillna(method='bfill').fillna(method='ffill')
    df['Atmospheric Pressure'] = df['Atmospheric Pressure'].rolling(window=10, center=True).mean().fillna(method='bfill').fillna(method='ffill')
    final.append(df)
# Out:
# C:\Users\20210291\AppData\Local\Temp\ipykernel_27284\3582036499.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[col] = df[col].rolling(window=15, center=True).mean().fillna(method='bfill').fillna(method='ffill')
# C:\Users\20210291\AppData\Local\Temp\ipykernel_27284\3582036499.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Atmospheric Pressure'] = df['Atmospheric Pressure'].rolling(window=10, center=True).mean().fillna(method='bfill').fillna(method='ffill')

# %%
for i in range(len(final)):
    final[i].to_csv('Datasets-Ready/'+names[i]+'_Ready.csv')

# %%
amman_test = pd.read_csv('Amman_test_data/amman_test.csv')
df = amman_test.copy()

# %%
df = datasets[i].copy()
for col in violent_columns:
    df[col] = df[col].rolling(window=15, center=True).mean().fillna(method='bfill').fillna(method='ffill')
df['Atmospheric Pressure'] = df['Atmospheric Pressure'].rolling(window=10, center=True).mean().fillna(method='bfill').fillna(method='ffill')
# Out:
# C:\Users\20210291\AppData\Local\Temp\ipykernel_27284\697499422.py:3: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df[col] = df[col].rolling(window=15, center=True).mean().fillna(method='bfill').fillna(method='ffill')
# C:\Users\20210291\AppData\Local\Temp\ipykernel_27284\697499422.py:4: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Atmospheric Pressure'] = df['Atmospheric Pressure'].rolling(window=10, center=True).mean().fillna(method='bfill').fillna(method='ffill')

# %%
tt = final[0].copy()

# %%
tt['Unnamed: 0'] = pd.to_datetime(tt['Unnamed: 0'])
tt.set_index('Unnamed: 0', inplace = True)

# %%
for i in range(len(final)):
    final[i]['Unnamed: 0'] = pd.to_datetime(final[i]['Unnamed: 0'])
    final[i].set_index('Unnamed: 0', inplace = True)
    final[i].to_csv('Datasets-Ready/'+names[i]+'_Ready.csv')

# %%
df['Unnamed: 0'] = pd.to_datetime(df['Unnamed: 0'])
df.set_index('Unnamed: 0', inplace = True)

# %%
df.drop(['Unnamed: 0.1'], inplace = True, axis = 1)

# %%
df.to_csv('Amman_test_data/amman_test.csv')

# %%
amman_test.tail()
# Out:
#         Unnamed: 0.1           Unnamed: 0  Air Dew Point  \
# 210371        210371  2023-12-31 14:00:00            8.9
# 210372        210372  2023-12-31 15:00:00            8.9
# 210373        210373  2023-12-31 16:00:00            8.9
# 210374        210374  2023-12-31 17:00:00            8.9
# 210375        210375  2023-12-31 18:00:00            8.9
#
#         Air Temperature (OC)  Humidity %  Atmospheric Pressure  \
# 210371                  13.0       88.83               1023.81
# 210372                  12.0       77.04               1023.81
# 210373                  12.0       77.04               1023.81
# 210374                  12.0       77.04               1023.81
# 210375                  10.0       87.38               1023.81
#
#         Liquid Precipitation  Cloud Cover %  Wind_U    Wind_V
# 210371                   0.0          51.39    -0.0  0.546667
# 210372                   0.0          56.06    -0.0  0.546667
# ...
